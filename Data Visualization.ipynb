# %% [markdown]
# # Loading Requied libraries
# > pandas for reading files and data analysis,
# > seaborn and matplotlib for visualization
# > warning to control warnings

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
# %matplotlib inline
warnings.filterwarnings("ignore")
pd.plotting.register_matplotlib_converters()

# %% [markdown]
# ## Loading required data

# %%
candy = pd.read_csv("candy.csv", index_col = "id")
museum_visitors = pd.read_csv("museum_visitors.csv", index_col="Date", parse_dates=True)
ign_scores = pd.read_csv("ign_scores.csv")
cancer_m = pd.read_csv("cancer_m.csv")
cancer_b = pd.read_csv("cancer_b.csv")

# %%
#data insights
candy.head(5)
# Out:
#    id competitorname chocolate fruity caramel peanutyalmondy nougat  \
# 0   0      100 Grand       Yes     No     Yes             No     No
# 1   1   3 Musketeers       Yes     No      No             No    Yes
# 2   2      Air Heads        No    Yes      No             No     No
# 3   3     Almond Joy       Yes     No      No            Yes     No
# 4   4      Baby Ruth       Yes     No     Yes            Yes    Yes
#
#   crispedricewafer hard  bar pluribus  sugarpercent  pricepercent  winpercent
# 0              Yes   No  Yes       No         0.732         0.860   66.971725
# 1               No   No  Yes       No         0.604         0.511   67.602936
# 2               No   No   No       No         0.906         0.511   52.341465
# 3               No   No  Yes       No         0.465         0.767   50.347546
# 4               No   No  Yes       No         0.604         0.767   56.914547

# %%
candy.columns
# Out:
# Index(['id', 'competitorname', 'chocolate', 'fruity', 'caramel',
#        'peanutyalmondy', 'nougat', 'crispedricewafer', 'hard', 'bar',
#        'pluribus', 'sugarpercent', 'pricepercent', 'winpercent'],
#       dtype='object')

# %%
candy.isnull().sum()
# Out:
# id                  0
# competitorname      0
# chocolate           0
# fruity              0
# caramel             0
# peanutyalmondy      0
# nougat              0
# crispedricewafer    0
# hard                0
# bar                 0
# pluribus            0
# sugarpercent        0
# pricepercent        0
# winpercent          0
# dtype: int64

# %%
candy.describe().T
# Out:
#               count       mean        std        min       25%        50%  \
# id             83.0  41.000000  24.103942   0.000000  20.50000  41.000000
# sugarpercent   83.0   0.489916   0.276498   0.034000   0.26700   0.465000
# pricepercent   83.0   0.472627   0.286503   0.011000   0.26100   0.465000
# winpercent     83.0  50.584908  14.748880  22.445341  39.16328  48.982651
#
#                     75%       max
# id            61.500000  82.00000
# sugarpercent   0.732000   0.98800
# pricepercent   0.703000   0.97600
# winpercent    60.332349  84.18029

# %%
candy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83 entries, 0 to 82
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                83 non-null     int64
#  1   competitorname    83 non-null     object
#  2   chocolate         83 non-null     object
#  3   fruity            83 non-null     object
#  4   caramel           83 non-null     object
#  5   peanutyalmondy    83 non-null     object
#  6   nougat            83 non-null     object
#  7   crispedricewafer  83 non-null     object
#  8   hard              83 non-null     object
#  9   bar               83 non-null     object
#  10  pluribus          83 non-null     object
#  11  sugarpercent      83 non-null     float64
#  12  pricepercent      83 non-null     float64
#  13  winpercent        83 non-null     float64
# dtypes: float64(3), int64(1), object(10)
# memory usage: 9.2+ KB

# %%
museum_visitors.head(5)
# Out:
#             Avila Adobe  Firehouse Museum  Chinese American Museum  \
# Date
# 2014-01-01        24778              4486                     1581
# 2014-02-01        18976              4172                     1785
# 2014-03-01        25231              7082                     3229
# 2014-04-01        26989              6756                     2129
# 2014-05-01        36883             10858                     3676
#
#             America Tropical Interpretive Center
# Date
# 2014-01-01                                  6602
# 2014-02-01                                  5029
# 2014-03-01                                  8129
# 2014-04-01                                  2824
# 2014-05-01                                 10694

# %%
museum_visitors.columns
# Out:
# Index(['Avila Adobe', 'Firehouse Museum', 'Chinese American Museum',
#        'America Tropical Interpretive Center'],
#       dtype='object')

# %%
museum_visitors.isnull().sum()
# Out:
# Avila Adobe                             0
# Firehouse Museum                        0
# Chinese American Museum                 0
# America Tropical Interpretive Center    0
# dtype: int64

# %%
museum_visitors.describe().T
# Out:
#                                       count          mean          std  \
# Avila Adobe                            59.0  24061.661017  5948.997414
# Firehouse Museum                       59.0   6472.830508  7471.196609
# Chinese American Museum                59.0   2721.254237  1165.585196
# America Tropical Interpretive Center   59.0   7107.016949  2561.671286
#
#                                           min      25%      50%      75%  \
# Avila Adobe                           14035.0  19469.5  23136.0  27502.0
# Firehouse Museum                       3306.0   4412.5   5181.0   6239.5
# Chinese American Museum                1073.0   2134.0   2419.0   2942.5
# America Tropical Interpretive Center   2824.0   5424.5   6602.0   7943.0
#
#                                           max
# Avila Adobe                           41242.0
# Firehouse Museum                      61192.0
# Chinese American Museum                7702.0
# America Tropical Interpretive Center  13490.0

# %%
museum_visitors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 59 entries, 2014-01-01 to 2018-11-01
# Data columns (total 4 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Avila Adobe                           59 non-null     int64
#  1   Firehouse Museum                      59 non-null     int64
#  2   Chinese American Museum               59 non-null     int64
#  3   America Tropical Interpretive Center  59 non-null     int64
# dtypes: int64(4)
# memory usage: 2.3 KB

# %%
ign_scores.head(5)
# Out:
#            Platform    Action  Action, Adventure  Adventure  Fighting  \
# 0         Dreamcast  6.882857           7.511111   6.281818  8.200000
# 1  Game Boy Advance  6.373077           7.507692   6.057143  6.226316
# 2    Game Boy Color  6.272727           8.166667   5.307692  4.500000
# 3          GameCube  6.532584           7.608333   6.753846  7.422222
# 4      Nintendo 3DS  6.670833           7.481818   7.414286  6.614286
#
#    Platformer    Puzzle       RPG    Racing   Shooter  Simulation    Sports  \
# 0    8.340000  8.088889  7.700000  7.042500  7.616667    7.628571  7.272222
# 1    6.970588  6.532143  7.542857  6.657143  6.444444    6.928571  6.694444
# 2    6.352941  6.583333  7.285714  5.897436  4.500000    5.900000  5.790698
# 3    6.665714  6.133333  7.890909  6.852632  6.981818    8.028571  7.481319
# 4    7.503448  8.000000  7.719231  6.900000  7.033333    7.700000  6.388889
#
#    Strategy
# 0  6.433333
# 1  7.175000
# 2  7.400000
# 3  7.116667
# 4  7.900000

# %%
ign_scores.columns
# Out:
# Index(['Platform', 'Action', 'Action, Adventure', 'Adventure', 'Fighting',
#        'Platformer', 'Puzzle', 'RPG', 'Racing', 'Shooter', 'Simulation',
#        'Sports', 'Strategy'],
#       dtype='object')

# %%
ign_scores.isnull().sum()
# Out:
# Platform             0
# Action               0
# Action, Adventure    0
# Adventure            0
# Fighting             0
# Platformer           0
# Puzzle               0
# RPG                  0
# Racing               0
# Shooter              0
# Simulation           0
# Sports               0
# Strategy             0
# dtype: int64

# %%
ign_scores.describe().T
# Out:
#                    count      mean       std       min       25%       50%  \
# Action              21.0  6.707490  0.442479  5.903608  6.467361  6.719048
# Action, Adventure   21.0  7.505402  0.495720  6.133333  7.294643  7.481818
# Adventure           21.0  6.762933  0.641049  5.307692  6.281818  6.821429
# Fighting            21.0  6.864066  0.812402  4.500000  6.553731  7.029630
# Platformer          21.0  7.304406  0.592512  6.352941  6.889655  7.250000
# Puzzle              21.0  7.044883  0.773113  5.125000  6.583333  6.924706
# RPG                 21.0  7.539589  0.520318  6.050000  7.285714  7.542857
# Racing              21.0  6.760007  0.636959  5.011667  6.563636  6.898305
# Shooter             21.0  7.010270  0.759933  4.500000  6.641667  7.033333
# Simulation          21.0  6.983722  0.951588  5.195652  6.327027  7.142857
# Sports              21.0  6.909593  0.626141  5.644444  6.694444  7.130000
# ...

# %%
ign_scores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Platform           21 non-null     object
#  1   Action             21 non-null     float64
#  2   Action, Adventure  21 non-null     float64
#  3   Adventure          21 non-null     float64
#  4   Fighting           21 non-null     float64
#  5   Platformer         21 non-null     float64
#  6   Puzzle             21 non-null     float64
#  7   RPG                21 non-null     float64
#  8   Racing             21 non-null     float64
#  9   Shooter            21 non-null     float64
#  10  Simulation         21 non-null     float64
#  11  Sports             21 non-null     float64
#  12  Strategy           21 non-null     float64
# dtypes: float64(12), object(1)
# memory usage: 2.3+ KB

# %%
ign_scores.shape
# Out:
# (21, 13)

# %%
cancer_b.head(5)
# Out:
#          Id Diagnosis  Radius (mean)  Texture (mean)  Perimeter (mean)  \
# 0   8510426         B         13.540           14.36             87.46
# 1   8510653         B         13.080           15.71             85.63
# 2   8510824         B          9.504           12.44             60.34
# 3    854941         B         13.030           18.42             82.61
# 4  85713702         B          8.196           16.84             51.71
#
#    Area (mean)  Smoothness (mean)  Compactness (mean)  Concavity (mean)  \
# 0        566.3            0.09779             0.08129           0.06664
# 1        520.0            0.10750             0.12700           0.04568
# 2        273.9            0.10240             0.06492           0.02956
# 3        523.8            0.08983             0.03766           0.02562
# 4        201.9            0.08600             0.05943           0.01588
#
#    Concave points (mean)  ...  Radius (worst)  Texture (worst)  \
# ...

# %%
cancer_b.shape
# Out:
# (357, 32)

# %%
cancer_b.columns
# Out:
# Index(['Id', 'Diagnosis', 'Radius (mean)', 'Texture (mean)',
#        'Perimeter (mean)', 'Area (mean)', 'Smoothness (mean)',
#        'Compactness (mean)', 'Concavity (mean)', 'Concave points (mean)',
#        'Symmetry (mean)', 'Fractal dimension (mean)', 'Radius (se)',
#        'Texture (se)', 'Perimeter (se)', 'Area (se)', 'Smoothness (se)',
#        'Compactness (se)', 'Concavity (se)', 'Concave points (se)',
#        'Symmetry (se)', 'Fractal dimension (se)', 'Radius (worst)',
#        'Texture (worst)', 'Perimeter (worst)', 'Area (worst)',
#        'Smoothness (worst)', 'Compactness (worst)', 'Concavity (worst)',
#        'Concave points (worst)', 'Symmetry (worst)',
#        'Fractal dimension (worst)'],
#       dtype='object')

# %%
cancer_b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 32 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Id                         357 non-null    int64
#  1   Diagnosis                  357 non-null    object
#  2   Radius (mean)              357 non-null    float64
#  3   Texture (mean)             357 non-null    float64
#  4   Perimeter (mean)           357 non-null    float64
#  5   Area (mean)                357 non-null    float64
#  6   Smoothness (mean)          357 non-null    float64
#  7   Compactness (mean)         357 non-null    float64
#  8   Concavity (mean)           357 non-null    float64
#  9   Concave points (mean)      357 non-null    float64
#  10  Symmetry (mean)            357 non-null    float64
#  11  Fractal dimension (mean)   357 non-null    float64
#  12  Radius (se)                357 non-null    float64
# ...

# %%
cancer_b.describe().T
# Out:
#                            count          mean           std          min  \
# Id                         357.0  2.654382e+07  1.167397e+08  8913.000000
# Radius (mean)              357.0  1.214652e+01  1.780512e+00     6.981000
# Texture (mean)             357.0  1.791476e+01  3.995125e+00     9.710000
# Perimeter (mean)           357.0  7.807541e+01  1.180744e+01    43.790000
# Area (mean)                357.0  4.627902e+02  1.342871e+02   143.500000
# Smoothness (mean)          357.0  9.247765e-02  1.344608e-02     0.052630
# Compactness (mean)         357.0  8.008462e-02  3.374995e-02     0.019380
# Concavity (mean)           357.0  4.605762e-02  4.344215e-02     0.000000
# Concave points (mean)      357.0  2.571741e-02  1.590878e-02     0.000000
# Symmetry (mean)            357.0  1.741860e-01  2.480676e-02     0.106000
# Fractal dimension (mean)   357.0  6.286739e-02  6.747343e-03     0.051850
# Radius (se)                357.0  2.840824e-01  1.125696e-01     0.111500
# ...

# %% [markdown]
# # Line chart
# It is used to shows trends in data

# %%
plt.figure(figsize=(10,10))
sns.set_style('darkgrid');
plt.figure(figsize=(16,4))
plt.title("No of visitors to LA meusuems")
sns.lineplot(data = museum_visitors)
plt.show();

# %% [markdown]
# As clear from the figure, the number of visitors to Firehouse Museum in 2014-2015 is greater than the no of visitors to any other museum. On average, the Avila Adobe Museum has the greater number of visitors.

# %%
#visitors to avila adobe
plt.figure(figsize = (10,3))
plt.title("Visitors to Avila Adobe Museum")
plt.ylabel("Number of visitors")
sns.lineplot(data = museum_visitors["Avila Adobe"])
plt.show();

# %%
#visitors to chineese american museum
plt.figure(figsize = (10,3))
plt.title("Visitors to ChineeseAmerican Mueusum")
plt.ylabel("Number of visitors")
sns.lineplot(data = museum_visitors["Chinese American Museum"])
plt.show();

# %%
#visitors to Firehouse Museum
plt.figure(figsize =(10,2))
plt.title("visitors to Firehouse Museum")
plt.ylabel("Numbr of visitors")
sns.lineplot(data = museum_visitors["Firehouse Museum"])
plt.show();

# %%
#visitors to America Tropical Interpretive Center
plt.figure(figsize =(10,2))
plt.title("visitors to America Tropical Interpretive Center")
plt.ylabel("Number of visitors")
sns.lineplot(data = museum_visitors["America Tropical Interpretive Center"])
plt.show();

# %% [markdown]
# # Bar chart

# %%
#bar chart showing average score for  racing for game by platform
plt.figure(figsize=(16,5))
plt.title("Average score for racing by Platform")
sns.barplot(x = ign_scores["Racing"], y = ign_scores.index, data = ign_scores)
plt.ylabel("Score")
plt.xlabel("Platform")
plt.show()

# %%
plt.figure(figsize =(20,5))
sns.barplot(x = ign_scores['Puzzle'], y = ign_scores.index)
plt.title("average score for puzzle game")
plt.xlabel('Puzle game')
plt.show();

# %% [markdown]
# # Histogram
# A histogram is a graph that shows the frequency of numerical data using rectangles. The height of a rectangle (the vertical axis) represents the distribution frequency of a variable (the amount, or how often that variable appears).

# %%
#plotting histogram
plt.figure(figsize =(16,8))
plt.title("Histogram to shows the frequency of Malignent and Benign Tumor")
sns.distplot(a = cancer_m["Area (mean)"], label="Malignent", kde = False)
sns.distplot(a = cancer_b["Area (mean)"], label="Benign", kde = False)
plt.legend()
plt.show();

# %% [markdown]
# The above histogram shows that the mean area of tumor for bengin is between 200 and 100 while malignent tumor has mean are between 400 and 2000.

# %%
plt.figure(figsize=(16,8))
sns.kdeplot(data=cancer_b["Radius (worst)"], label = "Benign", shade = True)
sns.kdeplot(data=cancer_m["Radius (worst)"], label = "Malignant", shade = True)
plt.legend()
plt.show()

# %% [markdown]
# # Scatter Plot

# %%
candy.head()
# Out:
#    competitorname chocolate fruity caramel peanutyalmondy nougat  \
# id
# 0       100 Grand       Yes     No     Yes             No     No
# 1    3 Musketeers       Yes     No      No             No    Yes
# 2       Air Heads        No    Yes      No             No     No
# 3      Almond Joy       Yes     No      No            Yes     No
# 4       Baby Ruth       Yes     No     Yes            Yes    Yes
#
#    crispedricewafer hard  bar pluribus  sugarpercent  pricepercent  winpercent
# id
# 0               Yes   No  Yes       No         0.732         0.860   66.971725
# 1                No   No  Yes       No         0.604         0.511   67.602936
# 2                No   No   No       No         0.906         0.511   52.341465
# 3                No   No  Yes       No         0.465         0.767   50.347546
# 4                No   No  Yes       No         0.604         0.767   56.914547

# %% [markdown]
# Do people tend to prefer candies with higher sugar content?

# %% [markdown]
# Create a scatter plot that shows the relationship between 'sugarpercent' (on the horizontal x-axis) and 'winpercent' (on the vertical y-axis).

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x = candy["sugarpercent"], y = candy["winpercent"])
plt.show();

# %% [markdown]
# The scatter plot does not show a strong correlation between the two variables. Since there is no clear relationship between the two variables, this tells us that sugar content does not play a strong role in candy popularity

# %% [markdown]
# Create the same scatter plot with regression line to take a closer look

# %%
plt.figure(figsize=(16,8))
sns.regplot(x = candy["sugarpercent"], y = candy["winpercent"], data = candy)
plt.show();

# %% [markdown]
# Since the regression line has a slightly positive slope, this tells us that there is a slightly positive correlation between 'winpercent' and 'sugarpercent'. Thus, people have a slight preference for candies containing relatively more sugar.

# %% [markdown]
# create a scatter plot to show the relationship between 'pricepercent' (on the horizontal x-axis) and 'winpercent' (on the vertical y-axis). Use the 'chocolate' column to color-code the points.

# %%
plt.figure(figsize=(16,8))
sns.scatterplot(x = candy["pricepercent"], y = candy["winpercent"], hue=candy["chocolate"])
plt.show();

# %% [markdown]
# same scatterplot with regression line

# %%
plt.figure(figsize=(16,8))
sns.lmplot(x = "pricepercent", y = "winpercent",hue = "chocolate",data = candy)
plt.show();

# %% [markdown]
# We'll begin with the regression line for chocolate candies. Since this line has a slightly positive slope, we can say that more expensive chocolate candies tend to be more popular (than relatively cheaper chocolate candies). Likewise, since the regression line for candies without chocolate has a negative slope, we can say that if candies don't contain chocolate, they tend to be more popular when they are cheaper.

# %% [markdown]
# Create a categorical scatter plot to highlight the relationship between 'chocolate' and 'winpercent'

# %%
plt.figure(figsize=(10,10))
sns.swarmplot(x = "chocolate", y = "winpercent", data=candy)
plt.show();

# %% [markdown]
# # Heatmap

# %%
import numpy as np

# %%
uniform_data = np.random.rand(10, 12)
ax = sns.heatmap(uniform_data)
